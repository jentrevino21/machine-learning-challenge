# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied, skipping upgrade: scikit-learn in c:\users\jennifer\anaconda3\lib\site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\jennifer\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\jennifer\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\jennifer\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\jennifer\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.5.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1320 sha256=4c932ce07129dfc560546a87df104d6d23e66bb0d5a19f577eb8b8eba59c788c
#   Stored in directory: c:\users\jennifer\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\jennifer\anaconda3\lib\site-packages (0.16.0)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
X = df.drop(columns = "koi_disposition")
y = df["koi_disposition"]

# %%
df.groupby("koi_disposition").count()
# Out:
#                  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# koi_disposition
# CANDIDATE                 1687           1687           1687           1687
# CONFIRMED                 1800           1800           1800           1800
# FALSE POSITIVE            3504           3504           3504           3504
#
#                  koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# koi_disposition
# CANDIDATE              1687             1687             1687         1687
# CONFIRMED              1800             1800             1800         1800
# FALSE POSITIVE         3504             3504             3504         3504
#
#                  koi_time0bk_err1  koi_time0bk_err2  ...  koi_steff_err2  \
# koi_disposition                                      ...
# CANDIDATE                    1687              1687  ...            1687
# CONFIRMED                    1800              1800  ...            1800
# FALSE POSITIVE               3504              3504  ...            3504
#
#                  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# koi_disposition
# CANDIDATE             1687            1687            1687      1687
# CONFIRMED             1800            1800            1800      1800
# FALSE POSITIVE        3504            3504            3504      3504
#
#                  koi_srad_err1  koi_srad_err2    ra   dec  koi_kepmag
# koi_disposition
# CANDIDATE                 1687           1687  1687  1687        1687
# CONFIRMED                 1800           1800  1800  1800        1800
# FALSE POSITIVE            3504           3504  3504  3504        3504
#
# [3 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_train.head()

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# # Train the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=40))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               4100
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 14,503
# Trainable params: 14,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/60
# 164/164 - 0s - loss: 0.5757 - accuracy: 0.7141
# Epoch 2/60
# 164/164 - 0s - loss: 0.3806 - accuracy: 0.8045
# Epoch 3/60
# 164/164 - 0s - loss: 0.3692 - accuracy: 0.8102
# Epoch 4/60
# 164/164 - 0s - loss: 0.3603 - accuracy: 0.8138
# Epoch 5/60
# 164/164 - 0s - loss: 0.3493 - accuracy: 0.8272
# Epoch 6/60
# 164/164 - 0s - loss: 0.3414 - accuracy: 0.8358
# Epoch 7/60
# 164/164 - 0s - loss: 0.3311 - accuracy: 0.8453
# Epoch 8/60
# 164/164 - 0s - loss: 0.3275 - accuracy: 0.8421
# Epoch 9/60
# 164/164 - 0s - loss: 0.3223 - accuracy: 0.8465
# Epoch 10/60
# 164/164 - 0s - loss: 0.3165 - accuracy: 0.8529
# Epoch 11/60
# 164/164 - 0s - loss: 0.3222 - accuracy: 0.8577
# Epoch 12/60
# 164/164 - 0s - loss: 0.3193 - accuracy: 0.8486
# Epoch 13/60
# 164/164 - 0s - loss: 0.3078 - accuracy: 0.8566
# Epoch 14/60
# 164/164 - 0s - loss: 0.3046 - accuracy: 0.8621
# Epoch 15/60
# 164/164 - 0s - loss: 0.3061 - accuracy: 0.8632
# Epoch 16/60
# 164/164 - 0s - loss: 0.3041 - accuracy: 0.8638
# Epoch 17/60
# 164/164 - 0s - loss: 0.3075 - accuracy: 0.8629
# Epoch 18/60
# 164/164 - 0s - loss: 0.2996 - accuracy: 0.8682
# Epoch 19/60
# 164/164 - 0s - loss: 0.2914 - accuracy: 0.8720
# Epoch 20/60
# 164/164 - 0s - loss: 0.2920 - accuracy: 0.8707
# Epoch 21/60
# 164/164 - 0s - loss: 0.3057 - accuracy: 0.8579
# Epoch 22/60
# 164/164 - 0s - loss: 0.2910 - accuracy: 0.8749
# Epoch 23/60
# 164/164 - 0s - loss: 0.2903 - accuracy: 0.8732
# Epoch 24/60
# 164/164 - 0s - loss: 0.2826 - accuracy: 0.8804
# Epoch 25/60
# 164/164 - 0s - loss: 0.2884 - accuracy: 0.8680
# Epoch 26/60
# 164/164 - 0s - loss: 0.2835 - accuracy: 0.8795
# Epoch 27/60
# 164/164 - 0s - loss: 0.2897 - accuracy: 0.8695
# Epoch 28/60
# 164/164 - 0s - loss: 0.2819 - accuracy: 0.8743
# Epoch 29/60
# 164/164 - 0s - loss: 0.2810 - accuracy: 0.8772
# Epoch 30/60
# 164/164 - 0s - loss: 0.2786 - accuracy: 0.8776
# Epoch 31/60
# 164/164 - 0s - loss: 0.2776 - accuracy: 0.8800
# Epoch 32/60
# 164/164 - 0s - loss: 0.2749 - accuracy: 0.8787
# Epoch 33/60
# 164/164 - 0s - loss: 0.2766 - accuracy: 0.8791
# Epoch 34/60
# 164/164 - 0s - loss: 0.2727 - accuracy: 0.8821
# Epoch 35/60
# 164/164 - 0s - loss: 0.2747 - accuracy: 0.8772
# Epoch 36/60
# 164/164 - 0s - loss: 0.2724 - accuracy: 0.8789
# Epoch 37/60
# 164/164 - 0s - loss: 0.2717 - accuracy: 0.8802
# Epoch 38/60
# 164/164 - 0s - loss: 0.2680 - accuracy: 0.8796
# Epoch 39/60
# 164/164 - 0s - loss: 0.2705 - accuracy: 0.8793
# Epoch 40/60
# 164/164 - 0s - loss: 0.2660 - accuracy: 0.8823
# Epoch 41/60
# 164/164 - 0s - loss: 0.2633 - accuracy: 0.8844
# Epoch 42/60
# 164/164 - 0s - loss: 0.2672 - accuracy: 0.8806
# Epoch 43/60
# 164/164 - 0s - loss: 0.2609 - accuracy: 0.8867
# Epoch 44/60
# 164/164 - 0s - loss: 0.2588 - accuracy: 0.8875
# Epoch 45/60
# 164/164 - 0s - loss: 0.2625 - accuracy: 0.8833
# Epoch 46/60
# 164/164 - 0s - loss: 0.2567 - accuracy: 0.8884
# Epoch 47/60
# 164/164 - 0s - loss: 0.2596 - accuracy: 0.8819
# Epoch 48/60
# 164/164 - 0s - loss: 0.2593 - accuracy: 0.8873
# Epoch 49/60
# 164/164 - 0s - loss: 0.2576 - accuracy: 0.8846
# Epoch 50/60
# 164/164 - 0s - loss: 0.2584 - accuracy: 0.8850
# Epoch 51/60
# 164/164 - 0s - loss: 0.2581 - accuracy: 0.8837
# Epoch 52/60
# 164/164 - 0s - loss: 0.2513 - accuracy: 0.8898
# Epoch 53/60
# 164/164 - 0s - loss: 0.2561 - accuracy: 0.8869
# Epoch 54/60
# 164/164 - 0s - loss: 0.2536 - accuracy: 0.8867
# Epoch 55/60
# 164/164 - 0s - loss: 0.2524 - accuracy: 0.8903
# Epoch 56/60
# 164/164 - 0s - loss: 0.2528 - accuracy: 0.8875
# Epoch 57/60
# 164/164 - 0s - loss: 0.2459 - accuracy: 0.8924
# Epoch 58/60
# 164/164 - 0s - loss: 0.2498 - accuracy: 0.8907
# Epoch 59/60
# 164/164 - 0s - loss: 0.2447 - accuracy: 0.8896
# Epoch 60/60
# 164/164 - 0s - loss: 0.2519 - accuracy: 0.8877

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2344 - accuracy: 0.9010
# Normal Neural Network - Loss: 0.2344486266374588, Accuracy: 0.9010297656059265

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:5])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:5])}")
# Out:
# Predicted classes: ['CONFIRMED' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'FALSE POSITIVE']
# Actual Labels: ['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE']

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'deep_learning_model.sav'
joblib.dump(model, filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-8a5d0039d89b> in <module>
#       5 import joblib
#       6 filename = 'deep_learning_model.sav'
# ----> 7 joblib.dump(model, filename)
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
# --> 480             NumpyPickler(f, protocol=protocol).dump(value)
#     481     else:
#     482         NumpyPickler(filename, protocol=protocol).dump(value)
#
# ~\anaconda3\lib\pickle.py in dump(self, obj)
#     483         if self.proto >= 4:
#     484             self.framer.start_framing()
# --> 485         self.save(obj)
#     486         self.write(STOP)
#     487         self.framer.end_framing()
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\lib\pickle.py in save_list(self, obj)
#     927
#     928         self.memoize(obj)
# --> 929         self._batch_appends(obj)
#     930
#     931     dispatch[list] = save_list
#
# ~\anaconda3\lib\pickle.py in _batch_appends(self, items)
#     951                 write(MARK)
#     952                 for x in tmp:
# --> 953                     save(x)
#     954                 write(APPENDS)
#     955             elif n:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\lib\pickle.py in save_list(self, obj)
#     927
#     928         self.memoize(obj)
# --> 929         self._batch_appends(obj)
#     930
#     931     dispatch[list] = save_list
#
# ~\anaconda3\lib\pickle.py in _batch_appends(self, items)
#     954                 write(APPENDS)
#     955             elif n:
# --> 956                 save(tmp[0])
#     957                 write(APPEND)
#     958             # else tmp is empty, and we're done
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~\anaconda3\lib\pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~\anaconda3\lib\pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~\anaconda3\lib\pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~\anaconda3\lib\pickle.py in save(self, obj, save_persistent_id)
#     574                 reduce = getattr(obj, "__reduce_ex__", None)
#     575                 if reduce is not None:
# --> 576                     rv = reduce(self.proto)
#     577                 else:
#     578                     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle '_thread.RLock' object
